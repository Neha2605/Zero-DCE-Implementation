# %% [markdown]
# <a href="https://colab.research.google.com/github/Neha2605/Zero-DCE-Implementation/blob/main/Zero_dce_Implementation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Zero-DCE for low-light image enhancement
#
# **Description:** Implementing Zero-Reference Deep Curve Estimation for low-light image enhancement.

# %% [markdown]
# ## Introduction
#
# **Zero-Reference Deep Curve Estimation** or **Zero-DCE** formulates low-light image
# enhancement as the task of estimating an image-specific
# [*tonal curve*](https://en.wikipedia.org/wiki/Curve_(tonality)) with a deep neural network.
# In this implementation, I trained a lightweight deep network, **DCE-Net**, to estimate
# pixel-wise and high-order tonal curves for dynamic range adjustment of a given image.
#
# Zero-DCE takes a low-light image as input and produces high-order tonal curves as its output.
# These curves are then used for pixel-wise adjustment on the dynamic range of the input to
# obtain an enhanced image. The curve estimation process is done in such a way that it maintains
# the range of the enhanced image and preserves the contrast of neighboring pixels. This
# curve estimation is inspired by curves adjustment used in photo editing software such as
# Adobe Photoshop where users can adjust points throughout an image’s tonal range.
#
# Zero-DCE is appealing because of its relaxed assumptions with regard to reference images:
# it does not require any input/output image pairs during training.
# This is achieved through a set of carefully formulated non-reference loss functions,
# which implicitly measure the enhancement quality and guide the training of the network.

# %% [markdown]
# ## Downloading LOLDataset
#
# The **LoL Dataset** has been created for low-light image enhancement. It provides 485
# images for training and 15 for testing. Each image pair in the dataset consists of a
# low-light input image and its corresponding well-exposed reference image.

# %%
import os
import random
import numpy as np
from glob import glob
from PIL import Image, ImageOps
import matplotlib.pyplot as plt

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# !gdown https://drive.google.com/uc?id=1DdGIJ4PZPlF2ikl8mNM9V-PdVxVLbQi6
# !unzip -q lol_dataset.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1DdGIJ4PZPlF2ikl8mNM9V-PdVxVLbQi6
# To: /content/lol_dataset.zip
# 100% 347M/347M [00:01<00:00, 225MB/s]

# %% [markdown]
# ## Creating a TensorFlow Dataset
#
# We use 300 low-light images from the LoL Dataset training set for training, and we use
# the remaining 185 low-light images for validation. We resize the images to size `256 x
# 256` to be used for both training and validation. Note that in order to train the DCE-Net,
# we will not require the corresponding enhanced images.

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 16
MAX_TRAIN_IMAGES = 400


def load_data(image_path):
    image = tf.io.read_file(image_path)
    image = tf.image.decode_png(image, channels=3)
    image = tf.image.resize(images=image, size=[IMAGE_SIZE, IMAGE_SIZE])
    image = image / 255.0
    return image


def data_generator(low_light_images):
    dataset = tf.data.Dataset.from_tensor_slices((low_light_images))
    dataset = dataset.map(load_data, num_parallel_calls=tf.data.AUTOTUNE)
    dataset = dataset.batch(BATCH_SIZE, drop_remainder=True)
    return dataset


train_low_light_images = sorted(glob("./lol_dataset/our485/low/*"))[:MAX_TRAIN_IMAGES]
val_low_light_images = sorted(glob("./lol_dataset/our485/low/*"))[MAX_TRAIN_IMAGES:]
test_low_light_images = sorted(glob("./lol_dataset/eval15/low/*"))


train_dataset = data_generator(train_low_light_images)
val_dataset = data_generator(val_low_light_images)

print("Train Dataset:", train_dataset)
print("Validation Dataset:", val_dataset)
# Out:
# Train Dataset: <BatchDataset element_spec=TensorSpec(shape=(16, 256, 256, 3), dtype=tf.float32, name=None)>
# Validation Dataset: <BatchDataset element_spec=TensorSpec(shape=(16, 256, 256, 3), dtype=tf.float32, name=None)>

# %% [markdown]
# ## The Zero-DCE Framework
#
# The goal of DCE-Net is to estimate a set of best-fitting light-enhancement curves
# (LE-curves) given an input image. The framework then maps all pixels of the input’s RGB
# channels by applying the curves iteratively to obtain the final enhanced image.
#
# ### Understanding light-enhancement curves
#
# A ligh-enhancement curve is a kind of curve that can map a low-light image
# to its enhanced version automatically,
# where the self-adaptive curve parameters are solely dependent on the input image.
# When designing such a curve, three objectives should be taken into account:
#
# - Each pixel value of the enhanced image should be in the normalized range `[0,1]`, in order to
# avoid information loss induced by overflow truncation.
# - It should be monotonous, to preserve the contrast between neighboring pixels.
# - The shape of this curve should be as simple as possible,
# and the curve should be differentiable to allow backpropagation.
#
# The light-enhancement curve is separately applied to three RGB channels instead of solely on the
# illumination channel. The three-channel adjustment can better preserve the inherent color and reduce
# the risk of over-saturation.
#
# ![](https://li-chongyi.github.io/Zero-DCE_files/framework.png)
#
# ### DCE-Net
#
# The DCE-Net is a lightweight deep neural network that learns the mapping between an input
# image and its best-fitting curve parameter maps. The input to the DCE-Net is a low-light
# image while the outputs are a set of pixel-wise curve parameter maps for corresponding
# higher-order curves. It is a plain CNN of seven convolutional layers with symmetrical
# concatenation. Each layer consists of 32 convolutional kernels of size 3×3 and stride 1
# followed by the ReLU activation function. The last convolutional layer is followed by the
# Tanh activation function, which produces 24 parameter maps for 8 iterations, where each
# iteration requires three curve parameter maps for the three channels.
#
# ![](https://i.imgur.com/HtIg34W.png)

# %%
def build_dce_net():
    input_img = keras.Input(shape=[None, None, 3])
    conv1 = layers.Conv2D(
        32, (3, 3), strides=(1, 1), activation="relu", padding="same"
    )(input_img)
    conv2 = layers.Conv2D(
        32, (3, 3), strides=(1, 1), activation="relu", padding="same"
    )(conv1)
    conv3 = layers.Conv2D(
        32, (3, 3), strides=(1, 1), activation="relu", padding="same"
    )(conv2)
    conv4 = layers.Conv2D(
        32, (3, 3), strides=(1, 1), activation="relu", padding="same"
    )(conv3)
    int_con1 = layers.Concatenate(axis=-1)([conv4, conv3])
    conv5 = layers.Conv2D(
        32, (3, 3), strides=(1, 1), activation="relu", padding="same"
    )(int_con1)
    int_con2 = layers.Concatenate(axis=-1)([conv5, conv2])
    conv6 = layers.Conv2D(
        32, (3, 3), strides=(1, 1), activation="relu", padding="same"
    )(int_con2)
    int_con3 = layers.Concatenate(axis=-1)([conv6, conv1])
    x_r = layers.Conv2D(24, (3, 3), strides=(1, 1), activation="tanh", padding="same")(
        int_con3
    )
    return keras.Model(inputs=input_img, outputs=x_r)

# %% [markdown]
# ## Loss functions
#
# To enable zero-reference learning in DCE-Net, we use a set of differentiable
# zero-reference losses that allow us to evaluate the quality of enhanced images.

# %% [markdown]
# ### Color constancy loss
#
# The *color constancy loss* is used to correct the potential color deviations in the
# enhanced image.

# %%
def color_constancy_loss(x):
    mean_rgb = tf.reduce_mean(x, axis=(1, 2), keepdims=True)
    mr, mg, mb = mean_rgb[:, :, :, 0], mean_rgb[:, :, :, 1], mean_rgb[:, :, :, 2]
    d_rg = tf.square(mr - mg)
    d_rb = tf.square(mr - mb)
    d_gb = tf.square(mb - mg)
    return tf.sqrt(tf.square(d_rg) + tf.square(d_rb) + tf.square(d_gb))

# %% [markdown]
# ### Exposure loss
#
# To restrain under-/over-exposed regions, we use the *exposure control loss*.
# It measures the distance between the average intensity value of a local region
# and a preset well-exposedness level (set to `0.6`).

# %%
def exposure_loss(x, mean_val=0.6):
    x = tf.reduce_mean(x, axis=3, keepdims=True)
    mean = tf.nn.avg_pool2d(x, ksize=16, strides=16, padding="VALID")
    return tf.reduce_mean(tf.square(mean - mean_val))

# %% [markdown]
# ### Illumination smoothness loss
#
# To preserve the monotonicity relations between neighboring pixels, the
# *illumination smoothness loss* is added to each curve parameter map.

# %%
def illumination_smoothness_loss(x):
    batch_size = tf.shape(x)[0]
    h_x = tf.shape(x)[1]
    w_x = tf.shape(x)[2]
    count_h = (tf.shape(x)[2] - 1) * tf.shape(x)[3]
    count_w = tf.shape(x)[2] * (tf.shape(x)[3] - 1)
    h_tv = tf.reduce_sum(tf.square((x[:, 1:, :, :] - x[:, : h_x - 1, :, :])))
    w_tv = tf.reduce_sum(tf.square((x[:, :, 1:, :] - x[:, :, : w_x - 1, :])))
    batch_size = tf.cast(batch_size, dtype=tf.float32)
    count_h = tf.cast(count_h, dtype=tf.float32)
    count_w = tf.cast(count_w, dtype=tf.float32)
    return 2 * (h_tv / count_h + w_tv / count_w) / batch_size

# %% [markdown]
# ### Spatial consistency loss
#
# The *spatial consistency loss* encourages spatial coherence of the enhanced image by
# preserving the contrast between neighboring regions across the input image and its enhanced version.

# %%
class SpatialConsistencyLoss(keras.losses.Loss):
    def __init__(self, **kwargs):
        super(SpatialConsistencyLoss, self).__init__(reduction="none")

        self.left_kernel = tf.constant(
            [[[[0, 0, 0]], [[-1, 1, 0]], [[0, 0, 0]]]], dtype=tf.float32
        )
        self.right_kernel = tf.constant(
            [[[[0, 0, 0]], [[0, 1, -1]], [[0, 0, 0]]]], dtype=tf.float32
        )
        self.up_kernel = tf.constant(
            [[[[0, -1, 0]], [[0, 1, 0]], [[0, 0, 0]]]], dtype=tf.float32
        )
        self.down_kernel = tf.constant(
            [[[[0, 0, 0]], [[0, 1, 0]], [[0, -1, 0]]]], dtype=tf.float32
        )

    def call(self, y_true, y_pred):

        original_mean = tf.reduce_mean(y_true, 3, keepdims=True)
        enhanced_mean = tf.reduce_mean(y_pred, 3, keepdims=True)
        original_pool = tf.nn.avg_pool2d(
            original_mean, ksize=4, strides=4, padding="VALID"
        )
        enhanced_pool = tf.nn.avg_pool2d(
            enhanced_mean, ksize=4, strides=4, padding="VALID"
        )

        d_original_left = tf.nn.conv2d(
            original_pool, self.left_kernel, strides=[1, 1, 1, 1], padding="SAME"
        )
        d_original_right = tf.nn.conv2d(
            original_pool, self.right_kernel, strides=[1, 1, 1, 1], padding="SAME"
        )
        d_original_up = tf.nn.conv2d(
            original_pool, self.up_kernel, strides=[1, 1, 1, 1], padding="SAME"
        )
        d_original_down = tf.nn.conv2d(
            original_pool, self.down_kernel, strides=[1, 1, 1, 1], padding="SAME"
        )

        d_enhanced_left = tf.nn.conv2d(
            enhanced_pool, self.left_kernel, strides=[1, 1, 1, 1], padding="SAME"
        )
        d_enhanced_right = tf.nn.conv2d(
            enhanced_pool, self.right_kernel, strides=[1, 1, 1, 1], padding="SAME"
        )
        d_enhanced_up = tf.nn.conv2d(
            enhanced_pool, self.up_kernel, strides=[1, 1, 1, 1], padding="SAME"
        )
        d_enhanced_down = tf.nn.conv2d(
            enhanced_pool, self.down_kernel, strides=[1, 1, 1, 1], padding="SAME"
        )

        d_left = tf.square(d_original_left - d_enhanced_left)
        d_right = tf.square(d_original_right - d_enhanced_right)
        d_up = tf.square(d_original_up - d_enhanced_up)
        d_down = tf.square(d_original_down - d_enhanced_down)
        return d_left + d_right + d_up + d_down

# %% [markdown]
# ### Deep curve estimation model
#
# We implement the Zero-DCE framework as a Keras subclassed model.

# %%
class ZeroDCE(keras.Model):
    def __init__(self, **kwargs):
        super(ZeroDCE, self).__init__(**kwargs)
        self.dce_model = build_dce_net()

    def compile(self, learning_rate, **kwargs):
        super(ZeroDCE, self).compile(**kwargs)
        self.optimizer = keras.optimizers.Adam(learning_rate=learning_rate)
        self.spatial_constancy_loss = SpatialConsistencyLoss(reduction="none")

    def get_enhanced_image(self, data, output):
        r1 = output[:, :, :, :3]
        r2 = output[:, :, :, 3:6]
        r3 = output[:, :, :, 6:9]
        r4 = output[:, :, :, 9:12]
        r5 = output[:, :, :, 12:15]
        r6 = output[:, :, :, 15:18]
        r7 = output[:, :, :, 18:21]
        r8 = output[:, :, :, 21:24]
        x = data + r1 * (tf.square(data) - data)
        x = x + r2 * (tf.square(x) - x)
        x = x + r3 * (tf.square(x) - x)
        enhanced_image = x + r4 * (tf.square(x) - x)
        x = enhanced_image + r5 * (tf.square(enhanced_image) - enhanced_image)
        x = x + r6 * (tf.square(x) - x)
        x = x + r7 * (tf.square(x) - x)
        enhanced_image = x + r8 * (tf.square(x) - x)
        return enhanced_image

    def call(self, data):
        dce_net_output = self.dce_model(data)
        return self.get_enhanced_image(data, dce_net_output)

    def compute_losses(self, data, output):
        enhanced_image = self.get_enhanced_image(data, output)
        loss_illumination = 200 * illumination_smoothness_loss(output)
        loss_spatial_constancy = tf.reduce_mean(
            self.spatial_constancy_loss(enhanced_image, data)
        )
        loss_color_constancy = 5 * tf.reduce_mean(color_constancy_loss(enhanced_image))
        loss_exposure = 10 * tf.reduce_mean(exposure_loss(enhanced_image))
        total_loss = (
            loss_illumination
            + loss_spatial_constancy
            + loss_color_constancy
            + loss_exposure
        )
        return {
            "total_loss": total_loss,
            "illumination_smoothness_loss": loss_illumination,
            "spatial_constancy_loss": loss_spatial_constancy,
            "color_constancy_loss": loss_color_constancy,
            "exposure_loss": loss_exposure,
        }

    def train_step(self, data):
        with tf.GradientTape() as tape:
            output = self.dce_model(data)
            losses = self.compute_losses(data, output)
        gradients = tape.gradient(
            losses["total_loss"], self.dce_model.trainable_weights
        )
        self.optimizer.apply_gradients(zip(gradients, self.dce_model.trainable_weights))
        return losses

    def test_step(self, data):
        output = self.dce_model(data)
        return self.compute_losses(data, output)

    def save_weights(self, filepath, overwrite=True, save_format=None, options=None):
        """While saving the weights, we simply save the weights of the DCE-Net"""
        self.dce_model.save_weights(
            filepath, overwrite=overwrite, save_format=save_format, options=options
        )

    def load_weights(self, filepath, by_name=False, skip_mismatch=False, options=None):
        """While loading the weights, we simply load the weights of the DCE-Net"""
        self.dce_model.load_weights(
            filepath=filepath,
            by_name=by_name,
            skip_mismatch=skip_mismatch,
            options=options,
        )

# %% [markdown]
# ## Training

# %%
zero_dce_model = ZeroDCE()
zero_dce_model.compile(learning_rate=1e-4)
history = zero_dce_model.fit(train_dataset, validation_data=val_dataset, epochs=100)


def plot_result(item):
    plt.plot(history.history[item], label=item)
    plt.plot(history.history["val_" + item], label="val_" + item)
    plt.xlabel("Epochs")
    plt.ylabel(item)
    plt.title("Train and Validation {} Over Epochs".format(item), fontsize=14)
    plt.legend()
    plt.grid()
    plt.show()


plot_result("total_loss")
plot_result("illumination_smoothness_loss")
plot_result("spatial_constancy_loss")
plot_result("color_constancy_loss")
plot_result("exposure_loss")
# Out:
# Epoch 1/100
# 25/25 [==============================] - 22s 299ms/step - total_loss: 5.6168 - illumination_smoothness_loss: 2.6976 - spatial_constancy_loss: 6.9379e-05 - color_constancy_loss: 0.0031 - exposure_loss: 2.9161 - val_total_loss: 5.0033 - val_illumination_smoothness_loss: 2.0142 - val_spatial_constancy_loss: 6.2385e-05 - val_color_constancy_loss: 5.3501e-04 - val_exposure_loss: 2.9886
# Epoch 2/100
# 25/25 [==============================] - 7s 287ms/step - total_loss: 4.5716 - illumination_smoothness_loss: 1.6609 - spatial_constancy_loss: 7.4648e-05 - color_constancy_loss: 0.0030 - exposure_loss: 2.9077 - val_total_loss: 4.2512 - val_illumination_smoothness_loss: 1.2659 - val_spatial_constancy_loss: 5.6574e-05 - val_color_constancy_loss: 4.7161e-04 - val_exposure_loss: 2.9848
# Epoch 3/100
# 25/25 [==============================] - 7s 295ms/step - total_loss: 4.0525 - illumination_smoothness_loss: 1.1482 - spatial_constancy_loss: 7.6318e-05 - color_constancy_loss: 0.0030 - exposure_loss: 2.9013 - val_total_loss: 3.8631 - val_illumination_smoothness_loss: 0.8848 - val_spatial_constancy_loss: 6.8328e-05 - val_color_constancy_loss: 4.4751e-04 - val_exposure_loss: 2.9778
# Epoch 4/100
# 25/25 [==============================] - 8s 297ms/step - total_loss: 3.7497 - illumination_smoothness_loss: 0.8547 - spatial_constancy_loss: 9.9800e-05 - color_constancy_loss: 0.0030 - exposure_loss: 2.8918 - val_total_loss: 3.6287 - val_illumination_smoothness_loss: 0.6594 - val_spatial_constancy_loss: 9.4737e-05 - val_color_constancy_loss: 4.5455e-04 - val_exposure_loss: 2.9687
# Epoch 5/100
# 25/25 [==============================] - 8s 298ms/step - total_loss: 3.5514 - illumination_smoothness_loss: 0.6670 - spatial_constancy_loss: 1.3513e-04 - color_constancy_loss: 0.0031 - exposure_loss: 2.8812 - val_total_loss: 3.4693 - val_illumination_smoothness_loss: 0.5099 - val_spatial_constancy_loss: 1.3039e-04 - val_color_constancy_loss: 4.6307e-04 - val_exposure_loss: 2.9587
# Epoch 6/100
# 25/25 [==============================] - 8s 300ms/step - total_loss: 3.4106 - illumination_smoothness_loss: 0.5374 - spatial_constancy_loss: 1.7941e-04 - color_constancy_loss: 0.0032 - exposure_loss: 2.8698 - val_total_loss: 3.3554 - val_illumination_smoothness_loss: 0.4063 - val_spatial_constancy_loss: 1.7264e-04 - val_color_constancy_loss: 4.7583e-04 - val_exposure_loss: 2.9485
# Epoch 7/100
# 25/25 [==============================] - 8s 300ms/step - total_loss: 3.3039 - illumination_smoothness_loss: 0.4424 - spatial_constancy_loss: 2.3109e-04 - color_constancy_loss: 0.0032 - exposure_loss: 2.8580 - val_total_loss: 3.2697 - val_illumination_smoothness_loss: 0.3314 - val_spatial_constancy_loss: 2.2408e-04 - val_color_constancy_loss: 4.8715e-04 - val_exposure_loss: 2.9376
# Epoch 8/100
# 25/25 [==============================] - 8s 299ms/step - total_loss: 3.2197 - illumination_smoothness_loss: 0.3707 - spatial_constancy_loss: 2.9298e-04 - color_constancy_loss: 0.0033 - exposure_loss: 2.8454 - val_total_loss: 3.2025 - val_illumination_smoothness_loss: 0.2757 - val_spatial_constancy_loss: 2.8527e-04 - val_color_constancy_loss: 4.9997e-04 - val_exposure_loss: 2.9260
# Epoch 9/100
# 25/25 [==============================] - 8s 297ms/step - total_loss: 3.1520 - illumination_smoothness_loss: 0.3161 - spatial_constancy_loss: 3.6740e-04 - color_constancy_loss: 0.0035 - exposure_loss: 2.8320 - val_total_loss: 3.1486 - val_illumination_smoothness_loss: 0.2338 - val_spatial_constancy_loss: 3.5895e-04 - val_color_constancy_loss: 5.1788e-04 - val_exposure_loss: 2.9139
# Epoch 10/100
# 25/25 [==============================] - 7s 292ms/step - total_loss: 3.0956 - illumination_smoothness_loss: 0.2736 - spatial_constancy_loss: 4.5652e-04 - color_constancy_loss: 0.0036 - exposure_loss: 2.8180 - val_total_loss: 3.1035 - val_illumination_smoothness_loss: 0.2014 - val_spatial_constancy_loss: 4.4643e-04 - val_color_constancy_loss: 5.3895e-04 - val_exposure_loss: 2.9011
# Epoch 11/100
# 25/25 [==============================] - 8s 299ms/step - total_loss: 3.0471 - illumination_smoothness_loss: 0.2398 - spatial_constancy_loss: 5.6249e-04 - color_constancy_loss: 0.0037 - exposure_loss: 2.8030 - val_total_loss: 3.0655 - val_illumination_smoothness_loss: 0.1769 - val_spatial_constancy_loss: 5.5051e-04 - val_color_constancy_loss: 5.6536e-04 - val_exposure_loss: 2.8875
# Epoch 12/100
# 25/25 [==============================] - 7s 292ms/step - total_loss: 3.0040 - illumination_smoothness_loss: 0.2125 - spatial_constancy_loss: 6.8777e-04 - color_constancy_loss: 0.0039 - exposure_loss: 2.7870 - val_total_loss: 3.0320 - val_illumination_smoothness_loss: 0.1580 - val_spatial_constancy_loss: 6.7350e-04 - val_color_constancy_loss: 5.9517e-04 - val_exposure_loss: 2.8728
# Epoch 13/100
# 25/25 [==============================] - 8s 298ms/step - total_loss: 2.9648 - illumination_smoothness_loss: 0.1905 - spatial_constancy_loss: 8.3952e-04 - color_constancy_loss: 0.0041 - exposure_loss: 2.7693 - val_total_loss: 3.0017 - val_illumination_smoothness_loss: 0.1442 - val_spatial_constancy_loss: 8.2799e-04 - val_color_constancy_loss: 6.3240e-04 - val_exposure_loss: 2.8561
# Epoch 14/100
# 25/25 [==============================] - 8s 298ms/step - total_loss: 2.9280 - illumination_smoothness_loss: 0.1730 - spatial_constancy_loss: 0.0010 - color_constancy_loss: 0.0043 - exposure_loss: 2.7496 - val_total_loss: 2.9727 - val_illumination_smoothness_loss: 0.1336 - val_spatial_constancy_loss: 0.0010 - val_color_constancy_loss: 6.7274e-04 - val_exposure_loss: 2.8374
# Epoch 15/100
# 25/25 [==============================] - 7s 291ms/step - total_loss: 2.8923 - illumination_smoothness_loss: 0.1594 - spatial_constancy_loss: 0.0013 - color_constancy_loss: 0.0046 - exposure_loss: 2.7271 - val_total_loss: 2.9444 - val_illumination_smoothness_loss: 0.1267 - val_spatial_constancy_loss: 0.0013 - val_color_constancy_loss: 7.2718e-04 - val_exposure_loss: 2.8157
# Epoch 16/100
# 25/25 [==============================] - 8s 298ms/step - total_loss: 2.8566 - illumination_smoothness_loss: 0.1489 - spatial_constancy_loss: 0.0016 - color_constancy_loss: 0.0049 - exposure_loss: 2.7012 - val_total_loss: 2.9150 - val_illumination_smoothness_loss: 0.1229 - val_spatial_constancy_loss: 0.0016 - val_color_constancy_loss: 8.1000e-04 - val_exposure_loss: 2.7897
# Epoch 17/100
# 25/25 [==============================] - 8s 297ms/step - total_loss: 2.8178 - illumination_smoothness_loss: 0.1427 - spatial_constancy_loss: 0.0020 - color_constancy_loss: 0.0054 - exposure_loss: 2.6676 - val_total_loss: 2.8815 - val_illumination_smoothness_loss: 0.1238 - val_spatial_constancy_loss: 0.0022 - val_color_constancy_loss: 9.4820e-04 - val_exposure_loss: 2.7546
# Epoch 18/100
# 25/25 [==============================] - 7s 297ms/step - total_loss: 2.7700 - illumination_smoothness_loss: 0.1425 - spatial_constancy_loss: 0.0028 - color_constancy_loss: 0.0061 - exposure_loss: 2.6186 - val_total_loss: 2.8359 - val_illumination_smoothness_loss: 0.1324 - val_spatial_constancy_loss: 0.0032 - val_color_constancy_loss: 0.0012 - val_exposure_loss: 2.6991
# Epoch 19/100
# 25/25 [==============================] - 7s 292ms/step - total_loss: 2.6926 - illumination_smoothness_loss: 0.1540 - spatial_constancy_loss: 0.0047 - color_constancy_loss: 0.0078 - exposure_loss: 2.5260 - val_total_loss: 2.7440 - val_illumination_smoothness_loss: 0.1525 - val_spatial_constancy_loss: 0.0059 - val_color_constancy_loss: 0.0021 - val_exposure_loss: 2.5836
# Epoch 20/100
# 25/25 [==============================] - 8s 297ms/step - total_loss: 2.4675 - illumination_smoothness_loss: 0.1918 - spatial_constancy_loss: 0.0143 - color_constancy_loss: 0.0149 - exposure_loss: 2.2466 - val_total_loss: 2.3905 - val_illumination_smoothness_loss: 0.2442 - val_spatial_constancy_loss: 0.0288 - val_color_constancy_loss: 0.0084 - val_exposure_loss: 2.1091
# Epoch 21/100
# 25/25 [==============================] - 7s 291ms/step - total_loss: 1.7508 - illumination_smoothness_loss: 0.2815 - spatial_constancy_loss: 0.1209 - color_constancy_loss: 0.0546 - exposure_loss: 1.2938 - val_total_loss: 1.6737 - val_illumination_smoothness_loss: 0.2999 - val_spatial_constancy_loss: 0.2144 - val_color_constancy_loss: 0.0266 - val_exposure_loss: 1.1328
# Epoch 22/100
# 25/25 [==============================] - 8s 297ms/step - total_loss: 1.3621 - illumination_smoothness_loss: 0.2680 - spatial_constancy_loss: 0.2744 - color_constancy_loss: 0.0842 - exposure_loss: 0.7355 - val_total_loss: 1.5756 - val_illumination_smoothness_loss: 0.2050 - val_spatial_constancy_loss: 0.2152 - val_color_constancy_loss: 0.0315 - val_exposure_loss: 1.1239
# Epoch 23/100
# 25/25 [==============================] - 7s 292ms/step - total_loss: 1.2869 - illumination_smoothness_loss: 0.1964 - spatial_constancy_loss: 0.2584 - color_constancy_loss: 0.0704 - exposure_loss: 0.7617 - val_total_loss: 1.5301 - val_illumination_smoothness_loss: 0.1699 - val_spatial_constancy_loss: 0.2265 - val_color_constancy_loss: 0.0348 - val_exposure_loss: 1.0989
# Epoch 24/100
# 25/25 [==============================] - 7s 291ms/step - total_loss: 1.2608 - illumination_smoothness_loss: 0.1768 - spatial_constancy_loss: 0.2697 - color_constancy_loss: 0.0719 - exposure_loss: 0.7424 - val_total_loss: 1.5126 - val_illumination_smoothness_loss: 0.1560 - val_spatial_constancy_loss: 0.2311 - val_color_constancy_loss: 0.0351 - val_exposure_loss: 1.0904
# Epoch 25/100
# 25/25 [==============================] - 7s 292ms/step - total_loss: 1.2475 - illumination_smoothness_loss: 0.1645 - spatial_constancy_loss: 0.2705 - color_constancy_loss: 0.0723 - exposure_loss: 0.7402 - val_total_loss: 1.5027 - val_illumination_smoothness_loss: 0.1478 - val_spatial_constancy_loss: 0.2329 - val_color_constancy_loss: 0.0365 - val_exposure_loss: 1.0856
# Epoch 26/100
# 25/25 [==============================] - 7s 297ms/step - total_loss: 1.2342 - illumination_smoothness_loss: 0.1515 - spatial_constancy_loss: 0.2723 - color_constancy_loss: 0.0727 - exposure_loss: 0.7377 - val_total_loss: 1.4933 - val_illumination_smoothness_loss: 0.1408 - val_spatial_constancy_loss: 0.2371 - val_color_constancy_loss: 0.0371 - val_exposure_loss: 1.0783
# Epoch 27/100
# 25/25 [==============================] - 7s 292ms/step - total_loss: 1.2241 - illumination_smoothness_loss: 0.1417 - spatial_constancy_loss: 0.2748 - color_constancy_loss: 0.0729 - exposure_loss: 0.7348 - val_total_loss: 1.4867 - val_illumination_smoothness_loss: 0.1368 - val_spatial_constancy_loss: 0.2400 - val_color_constancy_loss: 0.0375 - val_exposure_loss: 1.0724
# Epoch 28/100
# 25/25 [==============================] - 7s 297ms/step - total_loss: 1.2156 - illumination_smoothness_loss: 0.1338 - spatial_constancy_loss: 0.2754 - color_constancy_loss: 0.0731 - exposure_loss: 0.7334 - val_total_loss: 1.4776 - val_illumination_smoothness_loss: 0.1285 - val_spatial_constancy_loss: 0.2395 - val_color_constancy_loss: 0.0373 - val_exposure_loss: 1.0724
# Epoch 29/100
# 25/25 [==============================] - 7s 297ms/step - total_loss: 1.2074 - illumination_smoothness_loss: 0.1255 - spatial_constancy_loss: 0.2769 - color_constancy_loss: 0.0732 - exposure_loss: 0.7318 - val_total_loss: 1.4696 - val_illumination_smoothness_loss: 0.1210 - val_spatial_constancy_loss: 0.2411 - val_color_constancy_loss: 0.0379 - val_exposure_loss: 1.0696
# Epoch 30/100
# 25/25 [==============================] - 8s 297ms/step - total_loss: 1.1994 - illumination_smoothness_loss: 0.1185 - spatial_constancy_loss: 0.2783 - color_constancy_loss: 0.0736 - exposure_loss: 0.7291 - val_total_loss: 1.4615 - val_illumination_smoothness_loss: 0.1134 - val_spatial_constancy_loss: 0.2411 - val_color_constancy_loss: 0.0375 - val_exposure_loss: 1.0695
# Epoch 31/100
# 25/25 [==============================] - 7s 297ms/step - total_loss: 1.1919 - illumination_smoothness_loss: 0.1111 - spatial_constancy_loss: 0.2794 - color_constancy_loss: 0.0738 - exposure_loss: 0.7276 - val_total_loss: 1.4553 - val_illumination_smoothness_loss: 0.1079 - val_spatial_constancy_loss: 0.2426 - val_color_constancy_loss: 0.0376 - val_exposure_loss: 1.0672
# Epoch 32/100
# 25/25 [==============================] - 7s 295ms/step - total_loss: 1.1881 - illumination_smoothness_loss: 0.1074 - spatial_constancy_loss: 0.2804 - color_constancy_loss: 0.0741 - exposure_loss: 0.7262 - val_total_loss: 1.4507 - val_illumination_smoothness_loss: 0.1031 - val_spatial_constancy_loss: 0.2423 - val_color_constancy_loss: 0.0376 - val_exposure_loss: 1.0677
# Epoch 33/100
# 25/25 [==============================] - 7s 296ms/step - total_loss: 1.1821 - illumination_smoothness_loss: 0.1018 - spatial_constancy_loss: 0.2805 - color_constancy_loss: 0.0741 - exposure_loss: 0.7257 - val_total_loss: 1.4456 - val_illumination_smoothness_loss: 0.0987 - val_spatial_constancy_loss: 0.2426 - val_color_constancy_loss: 0.0375 - val_exposure_loss: 1.0668
# Epoch 34/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.1765 - illumination_smoothness_loss: 0.0963 - spatial_constancy_loss: 0.2821 - color_constancy_loss: 0.0744 - exposure_loss: 0.7237 - val_total_loss: 1.4392 - val_illumination_smoothness_loss: 0.0922 - val_spatial_constancy_loss: 0.2433 - val_color_constancy_loss: 0.0375 - val_exposure_loss: 1.0662
# Epoch 35/100
# 25/25 [==============================] - 7s 296ms/step - total_loss: 1.1720 - illumination_smoothness_loss: 0.0923 - spatial_constancy_loss: 0.2825 - color_constancy_loss: 0.0744 - exposure_loss: 0.7227 - val_total_loss: 1.4358 - val_illumination_smoothness_loss: 0.0892 - val_spatial_constancy_loss: 0.2435 - val_color_constancy_loss: 0.0374 - val_exposure_loss: 1.0657
# Epoch 36/100
# 25/25 [==============================] - 7s 291ms/step - total_loss: 1.1686 - illumination_smoothness_loss: 0.0885 - spatial_constancy_loss: 0.2829 - color_constancy_loss: 0.0746 - exposure_loss: 0.7226 - val_total_loss: 1.4319 - val_illumination_smoothness_loss: 0.0846 - val_spatial_constancy_loss: 0.2432 - val_color_constancy_loss: 0.0376 - val_exposure_loss: 1.0666
# Epoch 37/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.1646 - illumination_smoothness_loss: 0.0848 - spatial_constancy_loss: 0.2840 - color_constancy_loss: 0.0747 - exposure_loss: 0.7211 - val_total_loss: 1.4276 - val_illumination_smoothness_loss: 0.0808 - val_spatial_constancy_loss: 0.2445 - val_color_constancy_loss: 0.0377 - val_exposure_loss: 1.0646
# Epoch 38/100
# 25/25 [==============================] - 7s 292ms/step - total_loss: 1.1627 - illumination_smoothness_loss: 0.0827 - spatial_constancy_loss: 0.2842 - color_constancy_loss: 0.0748 - exposure_loss: 0.7210 - val_total_loss: 1.4258 - val_illumination_smoothness_loss: 0.0795 - val_spatial_constancy_loss: 0.2449 - val_color_constancy_loss: 0.0378 - val_exposure_loss: 1.0636
# Epoch 39/100
# 25/25 [==============================] - 7s 297ms/step - total_loss: 1.1602 - illumination_smoothness_loss: 0.0799 - spatial_constancy_loss: 0.2854 - color_constancy_loss: 0.0751 - exposure_loss: 0.7199 - val_total_loss: 1.4189 - val_illumination_smoothness_loss: 0.0723 - val_spatial_constancy_loss: 0.2452 - val_color_constancy_loss: 0.0381 - val_exposure_loss: 1.0633
# Epoch 40/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.1583 - illumination_smoothness_loss: 0.0775 - spatial_constancy_loss: 0.2852 - color_constancy_loss: 0.0750 - exposure_loss: 0.7205 - val_total_loss: 1.4185 - val_illumination_smoothness_loss: 0.0733 - val_spatial_constancy_loss: 0.2477 - val_color_constancy_loss: 0.0387 - val_exposure_loss: 1.0588
# Epoch 41/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.1556 - illumination_smoothness_loss: 0.0742 - spatial_constancy_loss: 0.2859 - color_constancy_loss: 0.0752 - exposure_loss: 0.7204 - val_total_loss: 1.4171 - val_illumination_smoothness_loss: 0.0736 - val_spatial_constancy_loss: 0.2507 - val_color_constancy_loss: 0.0396 - val_exposure_loss: 1.0533
# Epoch 42/100
# 25/25 [==============================] - 7s 295ms/step - total_loss: 1.1512 - illumination_smoothness_loss: 0.0695 - spatial_constancy_loss: 0.2863 - color_constancy_loss: 0.0752 - exposure_loss: 0.7202 - val_total_loss: 1.4171 - val_illumination_smoothness_loss: 0.0750 - val_spatial_constancy_loss: 0.2530 - val_color_constancy_loss: 0.0397 - val_exposure_loss: 1.0494
# Epoch 43/100
# 25/25 [==============================] - 7s 291ms/step - total_loss: 1.1462 - illumination_smoothness_loss: 0.0644 - spatial_constancy_loss: 0.2874 - color_constancy_loss: 0.0757 - exposure_loss: 0.7187 - val_total_loss: 1.4124 - val_illumination_smoothness_loss: 0.0703 - val_spatial_constancy_loss: 0.2529 - val_color_constancy_loss: 0.0398 - val_exposure_loss: 1.0494
# Epoch 44/100
# 25/25 [==============================] - 7s 296ms/step - total_loss: 1.1430 - illumination_smoothness_loss: 0.0619 - spatial_constancy_loss: 0.2880 - color_constancy_loss: 0.0757 - exposure_loss: 0.7174 - val_total_loss: 1.4104 - val_illumination_smoothness_loss: 0.0689 - val_spatial_constancy_loss: 0.2541 - val_color_constancy_loss: 0.0399 - val_exposure_loss: 1.0475
# Epoch 45/100
# 25/25 [==============================] - 7s 295ms/step - total_loss: 1.1400 - illumination_smoothness_loss: 0.0590 - spatial_constancy_loss: 0.2888 - color_constancy_loss: 0.0759 - exposure_loss: 0.7163 - val_total_loss: 1.4074 - val_illumination_smoothness_loss: 0.0659 - val_spatial_constancy_loss: 0.2542 - val_color_constancy_loss: 0.0401 - val_exposure_loss: 1.0473
# Epoch 46/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.1376 - illumination_smoothness_loss: 0.0567 - spatial_constancy_loss: 0.2894 - color_constancy_loss: 0.0760 - exposure_loss: 0.7155 - val_total_loss: 1.4048 - val_illumination_smoothness_loss: 0.0635 - val_spatial_constancy_loss: 0.2545 - val_color_constancy_loss: 0.0399 - val_exposure_loss: 1.0469
# Epoch 47/100
# 25/25 [==============================] - 7s 295ms/step - total_loss: 1.1352 - illumination_smoothness_loss: 0.0543 - spatial_constancy_loss: 0.2895 - color_constancy_loss: 0.0761 - exposure_loss: 0.7152 - val_total_loss: 1.4021 - val_illumination_smoothness_loss: 0.0607 - val_spatial_constancy_loss: 0.2542 - val_color_constancy_loss: 0.0399 - val_exposure_loss: 1.0473
# Epoch 48/100
# 25/25 [==============================] - 7s 289ms/step - total_loss: 1.1332 - illumination_smoothness_loss: 0.0523 - spatial_constancy_loss: 0.2903 - color_constancy_loss: 0.0762 - exposure_loss: 0.7144 - val_total_loss: 1.4002 - val_illumination_smoothness_loss: 0.0591 - val_spatial_constancy_loss: 0.2549 - val_color_constancy_loss: 0.0401 - val_exposure_loss: 1.0461
# Epoch 49/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.1309 - illumination_smoothness_loss: 0.0501 - spatial_constancy_loss: 0.2903 - color_constancy_loss: 0.0763 - exposure_loss: 0.7143 - val_total_loss: 1.3977 - val_illumination_smoothness_loss: 0.0570 - val_spatial_constancy_loss: 0.2557 - val_color_constancy_loss: 0.0403 - val_exposure_loss: 1.0447
# Epoch 50/100
# 25/25 [==============================] - 7s 295ms/step - total_loss: 1.1289 - illumination_smoothness_loss: 0.0482 - spatial_constancy_loss: 0.2912 - color_constancy_loss: 0.0764 - exposure_loss: 0.7131 - val_total_loss: 1.3954 - val_illumination_smoothness_loss: 0.0546 - val_spatial_constancy_loss: 0.2554 - val_color_constancy_loss: 0.0403 - val_exposure_loss: 1.0450
# Epoch 51/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.1268 - illumination_smoothness_loss: 0.0461 - spatial_constancy_loss: 0.2914 - color_constancy_loss: 0.0764 - exposure_loss: 0.7130 - val_total_loss: 1.3934 - val_illumination_smoothness_loss: 0.0530 - val_spatial_constancy_loss: 0.2562 - val_color_constancy_loss: 0.0405 - val_exposure_loss: 1.0437
# Epoch 52/100
# 25/25 [==============================] - 7s 291ms/step - total_loss: 1.1247 - illumination_smoothness_loss: 0.0439 - spatial_constancy_loss: 0.2919 - color_constancy_loss: 0.0765 - exposure_loss: 0.7124 - val_total_loss: 1.3909 - val_illumination_smoothness_loss: 0.0503 - val_spatial_constancy_loss: 0.2556 - val_color_constancy_loss: 0.0404 - val_exposure_loss: 1.0445
# Epoch 53/100
# 25/25 [==============================] - 7s 291ms/step - total_loss: 1.1233 - illumination_smoothness_loss: 0.0429 - spatial_constancy_loss: 0.2920 - color_constancy_loss: 0.0765 - exposure_loss: 0.7119 - val_total_loss: 1.3892 - val_illumination_smoothness_loss: 0.0487 - val_spatial_constancy_loss: 0.2556 - val_color_constancy_loss: 0.0402 - val_exposure_loss: 1.0446
# Epoch 54/100
# 25/25 [==============================] - 7s 296ms/step - total_loss: 1.1218 - illumination_smoothness_loss: 0.0413 - spatial_constancy_loss: 0.2923 - color_constancy_loss: 0.0766 - exposure_loss: 0.7116 - val_total_loss: 1.3865 - val_illumination_smoothness_loss: 0.0459 - val_spatial_constancy_loss: 0.2552 - val_color_constancy_loss: 0.0402 - val_exposure_loss: 1.0453
# Epoch 55/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.1202 - illumination_smoothness_loss: 0.0398 - spatial_constancy_loss: 0.2924 - color_constancy_loss: 0.0767 - exposure_loss: 0.7113 - val_total_loss: 1.3854 - val_illumination_smoothness_loss: 0.0451 - val_spatial_constancy_loss: 0.2561 - val_color_constancy_loss: 0.0405 - val_exposure_loss: 1.0437
# Epoch 56/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.1184 - illumination_smoothness_loss: 0.0381 - spatial_constancy_loss: 0.2931 - color_constancy_loss: 0.0768 - exposure_loss: 0.7104 - val_total_loss: 1.3834 - val_illumination_smoothness_loss: 0.0434 - val_spatial_constancy_loss: 0.2563 - val_color_constancy_loss: 0.0405 - val_exposure_loss: 1.0433
# Epoch 57/100
# 25/25 [==============================] - 8s 296ms/step - total_loss: 1.1170 - illumination_smoothness_loss: 0.0366 - spatial_constancy_loss: 0.2935 - color_constancy_loss: 0.0768 - exposure_loss: 0.7101 - val_total_loss: 1.3813 - val_illumination_smoothness_loss: 0.0411 - val_spatial_constancy_loss: 0.2558 - val_color_constancy_loss: 0.0404 - val_exposure_loss: 1.0440
# Epoch 58/100
# 25/25 [==============================] - 7s 296ms/step - total_loss: 1.1158 - illumination_smoothness_loss: 0.0355 - spatial_constancy_loss: 0.2935 - color_constancy_loss: 0.0769 - exposure_loss: 0.7100 - val_total_loss: 1.3809 - val_illumination_smoothness_loss: 0.0411 - val_spatial_constancy_loss: 0.2566 - val_color_constancy_loss: 0.0407 - val_exposure_loss: 1.0425
# Epoch 59/100
# 25/25 [==============================] - 7s 296ms/step - total_loss: 1.1145 - illumination_smoothness_loss: 0.0341 - spatial_constancy_loss: 0.2940 - color_constancy_loss: 0.0769 - exposure_loss: 0.7094 - val_total_loss: 1.3792 - val_illumination_smoothness_loss: 0.0396 - val_spatial_constancy_loss: 0.2566 - val_color_constancy_loss: 0.0406 - val_exposure_loss: 1.0424
# Epoch 60/100
# 25/25 [==============================] - 7s 289ms/step - total_loss: 1.1133 - illumination_smoothness_loss: 0.0331 - spatial_constancy_loss: 0.2941 - color_constancy_loss: 0.0770 - exposure_loss: 0.7091 - val_total_loss: 1.3784 - val_illumination_smoothness_loss: 0.0389 - val_spatial_constancy_loss: 0.2569 - val_color_constancy_loss: 0.0409 - val_exposure_loss: 1.0417
# Epoch 61/100
# 25/25 [==============================] - 7s 289ms/step - total_loss: 1.1124 - illumination_smoothness_loss: 0.0321 - spatial_constancy_loss: 0.2945 - color_constancy_loss: 0.0770 - exposure_loss: 0.7087 - val_total_loss: 1.3771 - val_illumination_smoothness_loss: 0.0380 - val_spatial_constancy_loss: 0.2577 - val_color_constancy_loss: 0.0411 - val_exposure_loss: 1.0403
# Epoch 62/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.1107 - illumination_smoothness_loss: 0.0309 - spatial_constancy_loss: 0.2945 - color_constancy_loss: 0.0771 - exposure_loss: 0.7083 - val_total_loss: 1.3748 - val_illumination_smoothness_loss: 0.0356 - val_spatial_constancy_loss: 0.2574 - val_color_constancy_loss: 0.0411 - val_exposure_loss: 1.0406
# Epoch 63/100
# 25/25 [==============================] - 7s 296ms/step - total_loss: 1.1099 - illumination_smoothness_loss: 0.0293 - spatial_constancy_loss: 0.2954 - color_constancy_loss: 0.0771 - exposure_loss: 0.7081 - val_total_loss: 1.3733 - val_illumination_smoothness_loss: 0.0331 - val_spatial_constancy_loss: 0.2554 - val_color_constancy_loss: 0.0407 - val_exposure_loss: 1.0441
# Epoch 64/100
# 25/25 [==============================] - 7s 297ms/step - total_loss: 1.1096 - illumination_smoothness_loss: 0.0294 - spatial_constancy_loss: 0.2941 - color_constancy_loss: 0.0769 - exposure_loss: 0.7093 - val_total_loss: 1.3739 - val_illumination_smoothness_loss: 0.0353 - val_spatial_constancy_loss: 0.2582 - val_color_constancy_loss: 0.0412 - val_exposure_loss: 1.0392
# Epoch 65/100
# 25/25 [==============================] - 7s 291ms/step - total_loss: 1.1082 - illumination_smoothness_loss: 0.0285 - spatial_constancy_loss: 0.2958 - color_constancy_loss: 0.0772 - exposure_loss: 0.7067 - val_total_loss: 1.3729 - val_illumination_smoothness_loss: 0.0341 - val_spatial_constancy_loss: 0.2578 - val_color_constancy_loss: 0.0412 - val_exposure_loss: 1.0398
# Epoch 66/100
# 25/25 [==============================] - 7s 291ms/step - total_loss: 1.1075 - illumination_smoothness_loss: 0.0277 - spatial_constancy_loss: 0.2952 - color_constancy_loss: 0.0771 - exposure_loss: 0.7074 - val_total_loss: 1.3714 - val_illumination_smoothness_loss: 0.0331 - val_spatial_constancy_loss: 0.2588 - val_color_constancy_loss: 0.0414 - val_exposure_loss: 1.0381
# Epoch 67/100
# 25/25 [==============================] - 7s 295ms/step - total_loss: 1.1062 - illumination_smoothness_loss: 0.0264 - spatial_constancy_loss: 0.2960 - color_constancy_loss: 0.0772 - exposure_loss: 0.7066 - val_total_loss: 1.3695 - val_illumination_smoothness_loss: 0.0309 - val_spatial_constancy_loss: 0.2575 - val_color_constancy_loss: 0.0410 - val_exposure_loss: 1.0402
# Epoch 68/100
# 25/25 [==============================] - 7s 296ms/step - total_loss: 1.1059 - illumination_smoothness_loss: 0.0261 - spatial_constancy_loss: 0.2958 - color_constancy_loss: 0.0773 - exposure_loss: 0.7067 - val_total_loss: 1.3705 - val_illumination_smoothness_loss: 0.0325 - val_spatial_constancy_loss: 0.2591 - val_color_constancy_loss: 0.0415 - val_exposure_loss: 1.0374
# Epoch 69/100
# 25/25 [==============================] - 7s 295ms/step - total_loss: 1.1046 - illumination_smoothness_loss: 0.0250 - spatial_constancy_loss: 0.2961 - color_constancy_loss: 0.0773 - exposure_loss: 0.7062 - val_total_loss: 1.3682 - val_illumination_smoothness_loss: 0.0304 - val_spatial_constancy_loss: 0.2593 - val_color_constancy_loss: 0.0415 - val_exposure_loss: 1.0370
# Epoch 70/100
# 25/25 [==============================] - 7s 296ms/step - total_loss: 1.1037 - illumination_smoothness_loss: 0.0246 - spatial_constancy_loss: 0.2966 - color_constancy_loss: 0.0774 - exposure_loss: 0.7051 - val_total_loss: 1.3682 - val_illumination_smoothness_loss: 0.0300 - val_spatial_constancy_loss: 0.2588 - val_color_constancy_loss: 0.0417 - val_exposure_loss: 1.0376
# Epoch 71/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.1030 - illumination_smoothness_loss: 0.0234 - spatial_constancy_loss: 0.2962 - color_constancy_loss: 0.0773 - exposure_loss: 0.7061 - val_total_loss: 1.3668 - val_illumination_smoothness_loss: 0.0293 - val_spatial_constancy_loss: 0.2597 - val_color_constancy_loss: 0.0417 - val_exposure_loss: 1.0361
# Epoch 72/100
# 25/25 [==============================] - 7s 291ms/step - total_loss: 1.1024 - illumination_smoothness_loss: 0.0230 - spatial_constancy_loss: 0.2972 - color_constancy_loss: 0.0775 - exposure_loss: 0.7047 - val_total_loss: 1.3658 - val_illumination_smoothness_loss: 0.0278 - val_spatial_constancy_loss: 0.2586 - val_color_constancy_loss: 0.0415 - val_exposure_loss: 1.0379
# Epoch 73/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.1017 - illumination_smoothness_loss: 0.0219 - spatial_constancy_loss: 0.2965 - color_constancy_loss: 0.0772 - exposure_loss: 0.7060 - val_total_loss: 1.3653 - val_illumination_smoothness_loss: 0.0272 - val_spatial_constancy_loss: 0.2582 - val_color_constancy_loss: 0.0413 - val_exposure_loss: 1.0386
# Epoch 74/100
# 25/25 [==============================] - 7s 296ms/step - total_loss: 1.1016 - illumination_smoothness_loss: 0.0223 - spatial_constancy_loss: 0.2967 - color_constancy_loss: 0.0774 - exposure_loss: 0.7052 - val_total_loss: 1.3661 - val_illumination_smoothness_loss: 0.0286 - val_spatial_constancy_loss: 0.2598 - val_color_constancy_loss: 0.0420 - val_exposure_loss: 1.0357
# Epoch 75/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.1006 - illumination_smoothness_loss: 0.0214 - spatial_constancy_loss: 0.2970 - color_constancy_loss: 0.0774 - exposure_loss: 0.7049 - val_total_loss: 1.3645 - val_illumination_smoothness_loss: 0.0275 - val_spatial_constancy_loss: 0.2603 - val_color_constancy_loss: 0.0419 - val_exposure_loss: 1.0348
# Epoch 76/100
# 25/25 [==============================] - 7s 291ms/step - total_loss: 1.1001 - illumination_smoothness_loss: 0.0210 - spatial_constancy_loss: 0.2975 - color_constancy_loss: 0.0776 - exposure_loss: 0.7040 - val_total_loss: 1.3640 - val_illumination_smoothness_loss: 0.0269 - val_spatial_constancy_loss: 0.2601 - val_color_constancy_loss: 0.0420 - val_exposure_loss: 1.0351
# Epoch 77/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.0992 - illumination_smoothness_loss: 0.0202 - spatial_constancy_loss: 0.2973 - color_constancy_loss: 0.0775 - exposure_loss: 0.7042 - val_total_loss: 1.3630 - val_illumination_smoothness_loss: 0.0261 - val_spatial_constancy_loss: 0.2602 - val_color_constancy_loss: 0.0419 - val_exposure_loss: 1.0347
# Epoch 78/100
# 25/25 [==============================] - 7s 296ms/step - total_loss: 1.0988 - illumination_smoothness_loss: 0.0198 - spatial_constancy_loss: 0.2976 - color_constancy_loss: 0.0776 - exposure_loss: 0.7038 - val_total_loss: 1.3623 - val_illumination_smoothness_loss: 0.0251 - val_spatial_constancy_loss: 0.2597 - val_color_constancy_loss: 0.0419 - val_exposure_loss: 1.0355
# Epoch 79/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.0981 - illumination_smoothness_loss: 0.0192 - spatial_constancy_loss: 0.2971 - color_constancy_loss: 0.0774 - exposure_loss: 0.7044 - val_total_loss: 1.3618 - val_illumination_smoothness_loss: 0.0251 - val_spatial_constancy_loss: 0.2604 - val_color_constancy_loss: 0.0421 - val_exposure_loss: 1.0342
# Epoch 80/100
# 25/25 [==============================] - 7s 288ms/step - total_loss: 1.0979 - illumination_smoothness_loss: 0.0190 - spatial_constancy_loss: 0.2982 - color_constancy_loss: 0.0776 - exposure_loss: 0.7030 - val_total_loss: 1.3618 - val_illumination_smoothness_loss: 0.0252 - val_spatial_constancy_loss: 0.2608 - val_color_constancy_loss: 0.0423 - val_exposure_loss: 1.0335
# Epoch 81/100
# 25/25 [==============================] - 7s 295ms/step - total_loss: 1.0974 - illumination_smoothness_loss: 0.0187 - spatial_constancy_loss: 0.2979 - color_constancy_loss: 0.0776 - exposure_loss: 0.7032 - val_total_loss: 1.3609 - val_illumination_smoothness_loss: 0.0241 - val_spatial_constancy_loss: 0.2604 - val_color_constancy_loss: 0.0422 - val_exposure_loss: 1.0342
# Epoch 82/100
# 25/25 [==============================] - 7s 289ms/step - total_loss: 1.0972 - illumination_smoothness_loss: 0.0183 - spatial_constancy_loss: 0.2975 - color_constancy_loss: 0.0775 - exposure_loss: 0.7039 - val_total_loss: 1.3609 - val_illumination_smoothness_loss: 0.0247 - val_spatial_constancy_loss: 0.2612 - val_color_constancy_loss: 0.0424 - val_exposure_loss: 1.0326
# Epoch 83/100
# 25/25 [==============================] - 7s 295ms/step - total_loss: 1.0965 - illumination_smoothness_loss: 0.0181 - spatial_constancy_loss: 0.2981 - color_constancy_loss: 0.0776 - exposure_loss: 0.7027 - val_total_loss: 1.3606 - val_illumination_smoothness_loss: 0.0242 - val_spatial_constancy_loss: 0.2610 - val_color_constancy_loss: 0.0424 - val_exposure_loss: 1.0330
# Epoch 84/100
# 25/25 [==============================] - 7s 296ms/step - total_loss: 1.0962 - illumination_smoothness_loss: 0.0174 - spatial_constancy_loss: 0.2979 - color_constancy_loss: 0.0775 - exposure_loss: 0.7034 - val_total_loss: 1.3599 - val_illumination_smoothness_loss: 0.0238 - val_spatial_constancy_loss: 0.2614 - val_color_constancy_loss: 0.0424 - val_exposure_loss: 1.0323
# Epoch 85/100
# 25/25 [==============================] - 8s 296ms/step - total_loss: 1.0955 - illumination_smoothness_loss: 0.0169 - spatial_constancy_loss: 0.2982 - color_constancy_loss: 0.0776 - exposure_loss: 0.7028 - val_total_loss: 1.3589 - val_illumination_smoothness_loss: 0.0225 - val_spatial_constancy_loss: 0.2606 - val_color_constancy_loss: 0.0422 - val_exposure_loss: 1.0336
# Epoch 86/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.0956 - illumination_smoothness_loss: 0.0168 - spatial_constancy_loss: 0.2983 - color_constancy_loss: 0.0777 - exposure_loss: 0.7029 - val_total_loss: 1.3596 - val_illumination_smoothness_loss: 0.0238 - val_spatial_constancy_loss: 0.2617 - val_color_constancy_loss: 0.0425 - val_exposure_loss: 1.0316
# Epoch 87/100
# 25/25 [==============================] - 7s 295ms/step - total_loss: 1.0950 - illumination_smoothness_loss: 0.0166 - spatial_constancy_loss: 0.2983 - color_constancy_loss: 0.0776 - exposure_loss: 0.7025 - val_total_loss: 1.3589 - val_illumination_smoothness_loss: 0.0231 - val_spatial_constancy_loss: 0.2617 - val_color_constancy_loss: 0.0426 - val_exposure_loss: 1.0316
# Epoch 88/100
# 25/25 [==============================] - 7s 289ms/step - total_loss: 1.0946 - illumination_smoothness_loss: 0.0162 - spatial_constancy_loss: 0.2986 - color_constancy_loss: 0.0777 - exposure_loss: 0.7022 - val_total_loss: 1.3585 - val_illumination_smoothness_loss: 0.0227 - val_spatial_constancy_loss: 0.2616 - val_color_constancy_loss: 0.0425 - val_exposure_loss: 1.0317
# Epoch 89/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.0943 - illumination_smoothness_loss: 0.0160 - spatial_constancy_loss: 0.2984 - color_constancy_loss: 0.0776 - exposure_loss: 0.7023 - val_total_loss: 1.3582 - val_illumination_smoothness_loss: 0.0226 - val_spatial_constancy_loss: 0.2620 - val_color_constancy_loss: 0.0427 - val_exposure_loss: 1.0309
# Epoch 90/100
# 25/25 [==============================] - 7s 297ms/step - total_loss: 1.0939 - illumination_smoothness_loss: 0.0156 - spatial_constancy_loss: 0.2987 - color_constancy_loss: 0.0777 - exposure_loss: 0.7019 - val_total_loss: 1.3578 - val_illumination_smoothness_loss: 0.0221 - val_spatial_constancy_loss: 0.2618 - val_color_constancy_loss: 0.0427 - val_exposure_loss: 1.0312
# Epoch 91/100
# 25/25 [==============================] - 7s 291ms/step - total_loss: 1.0935 - illumination_smoothness_loss: 0.0154 - spatial_constancy_loss: 0.2986 - color_constancy_loss: 0.0777 - exposure_loss: 0.7019 - val_total_loss: 1.3577 - val_illumination_smoothness_loss: 0.0222 - val_spatial_constancy_loss: 0.2622 - val_color_constancy_loss: 0.0428 - val_exposure_loss: 1.0304
# Epoch 92/100
# 25/25 [==============================] - 7s 295ms/step - total_loss: 1.0933 - illumination_smoothness_loss: 0.0151 - spatial_constancy_loss: 0.2990 - color_constancy_loss: 0.0777 - exposure_loss: 0.7014 - val_total_loss: 1.3572 - val_illumination_smoothness_loss: 0.0218 - val_spatial_constancy_loss: 0.2622 - val_color_constancy_loss: 0.0429 - val_exposure_loss: 1.0303
# Epoch 93/100
# 25/25 [==============================] - 7s 295ms/step - total_loss: 1.0928 - illumination_smoothness_loss: 0.0148 - spatial_constancy_loss: 0.2988 - color_constancy_loss: 0.0777 - exposure_loss: 0.7015 - val_total_loss: 1.3570 - val_illumination_smoothness_loss: 0.0215 - val_spatial_constancy_loss: 0.2621 - val_color_constancy_loss: 0.0429 - val_exposure_loss: 1.0305
# Epoch 94/100
# 25/25 [==============================] - 7s 296ms/step - total_loss: 1.0926 - illumination_smoothness_loss: 0.0146 - spatial_constancy_loss: 0.2990 - color_constancy_loss: 0.0777 - exposure_loss: 0.7013 - val_total_loss: 1.3566 - val_illumination_smoothness_loss: 0.0214 - val_spatial_constancy_loss: 0.2624 - val_color_constancy_loss: 0.0429 - val_exposure_loss: 1.0300
# Epoch 95/100
# 25/25 [==============================] - 8s 296ms/step - total_loss: 1.0924 - illumination_smoothness_loss: 0.0143 - spatial_constancy_loss: 0.2989 - color_constancy_loss: 0.0777 - exposure_loss: 0.7014 - val_total_loss: 1.3564 - val_illumination_smoothness_loss: 0.0212 - val_spatial_constancy_loss: 0.2627 - val_color_constancy_loss: 0.0431 - val_exposure_loss: 1.0294
# Epoch 96/100
# 25/25 [==============================] - 7s 291ms/step - total_loss: 1.0919 - illumination_smoothness_loss: 0.0140 - spatial_constancy_loss: 0.2993 - color_constancy_loss: 0.0778 - exposure_loss: 0.7009 - val_total_loss: 1.3556 - val_illumination_smoothness_loss: 0.0203 - val_spatial_constancy_loss: 0.2621 - val_color_constancy_loss: 0.0430 - val_exposure_loss: 1.0302
# Epoch 97/100
# 25/25 [==============================] - 7s 291ms/step - total_loss: 1.0915 - illumination_smoothness_loss: 0.0137 - spatial_constancy_loss: 0.2990 - color_constancy_loss: 0.0777 - exposure_loss: 0.7011 - val_total_loss: 1.3552 - val_illumination_smoothness_loss: 0.0201 - val_spatial_constancy_loss: 0.2624 - val_color_constancy_loss: 0.0431 - val_exposure_loss: 1.0297
# Epoch 98/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.0913 - illumination_smoothness_loss: 0.0135 - spatial_constancy_loss: 0.2992 - color_constancy_loss: 0.0777 - exposure_loss: 0.7009 - val_total_loss: 1.3549 - val_illumination_smoothness_loss: 0.0195 - val_spatial_constancy_loss: 0.2620 - val_color_constancy_loss: 0.0430 - val_exposure_loss: 1.0304
# Epoch 99/100
# 25/25 [==============================] - 7s 290ms/step - total_loss: 1.0913 - illumination_smoothness_loss: 0.0134 - spatial_constancy_loss: 0.2990 - color_constancy_loss: 0.0777 - exposure_loss: 0.7011 - val_total_loss: 1.3551 - val_illumination_smoothness_loss: 0.0200 - val_spatial_constancy_loss: 0.2625 - val_color_constancy_loss: 0.0432 - val_exposure_loss: 1.0294
# Epoch 100/100
# 25/25 [==============================] - 7s 297ms/step - total_loss: 1.0909 - illumination_smoothness_loss: 0.0133 - spatial_constancy_loss: 0.2993 - color_constancy_loss: 0.0777 - exposure_loss: 0.7006 - val_total_loss: 1.3543 - val_illumination_smoothness_loss: 0.0191 - val_spatial_constancy_loss: 0.2622 - val_color_constancy_loss: 0.0431 - val_exposure_loss: 1.0299

# %%
zero_dce_model.save_weights('./', overwrite=True, save_format=None, options=None)

# %% [markdown]
# ## Inference

# %%
def plot_results(images, titles, figure_size=(12, 12)):
    fig = plt.figure(figsize=figure_size)
    for i in range(len(images)):
        fig.add_subplot(1, len(images), i + 1).set_title(titles[i])
        _ = plt.imshow(images[i])
        plt.axis("off")
    plt.show()


def infer(original_image):
    image = keras.preprocessing.image.img_to_array(original_image)
    image = image.astype("float32") / 255.0
    image = np.expand_dims(image, axis=0)
    output_image = zero_dce_model(image)
    output_image = tf.cast((output_image[0, :, :, :] * 255), dtype=np.uint8)
    output_image = Image.fromarray(output_image.numpy())
    return output_image

# %% [markdown]
# ### Inference on test images
#
# We compare the test images from LOLDataset enhanced by MIRNet with images enhanced via
# the `PIL.ImageOps.autocontrast()` function.
#
# You can use the trained model hosted on [Hugging Face Hub](https://huggingface.co/keras-io/low-light-image-enhancement) and try the demo on [Hugging Face Spaces](https://huggingface.co/spaces/keras-io/low-light-image-enhancement).

# %%
for val_image_file in test_low_light_images:
    original_image = Image.open(val_image_file)
    enhanced_image = infer(original_image)
    plot_results(
        [original_image, ImageOps.autocontrast(original_image), enhanced_image],
        ["Original", "PIL Autocontrast", "Enhanced"],
        (20, 12),
    )
